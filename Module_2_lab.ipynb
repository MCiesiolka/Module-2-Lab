# %%
#

# %%
while True:
    last_name = input("Enter student's last name (or ZZZ to quit): ")

    if last_name == "ZZZ":
        break
    first_name = input("Enter student's first name: ")
    gpa = float(input("Enter student's GPA: "))

    # Check Dean's List
    if gpa >= 3.5:
        print(first_name, last_name, "has made the Dean's List.")

    elif gpa >= 3.25:
        print(first_name, last_name, "has made the Honor Roll.")

    else:
        print(first_name, last_name, "did not qualify.")

    print()
# Out:
# Enter student's last name (or ZZZ to quit):  Ciesiolka
# Enter student's first name:  Mark
# Enter student's GPA:  3.5
# Mark Ciesiolka has made the Dean's List.
# Enter student's last name (or ZZZ to quit):  Ciesiolka
# Enter student's first name:  Tanya
# Enter student's GPA:  4.0
# Tanya Ciesiolka has made the Dean's List.
# Enter student's last name (or ZZZ to quit):  Man
# Enter student's first name:  Dude
# Enter student's GPA:  3.25
# Dude Man has made the Honor Roll.
# Enter student's last name (or ZZZ to quit):  Guy
# Enter student's first name:  This
# Enter student's GPA:  3.49
# This Guy has made the Honor Roll.
# Enter student's last name (or ZZZ to quit):  Boy
# Enter student's first name:  Slacker
# Enter student's GPA:  1.0
# Slacker Boy did not qualify.
# Enter student's last name (or ZZZ to quit):  ZZZ
